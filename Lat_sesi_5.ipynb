# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.precision",2)

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...      60.31     GSW
# 126310         102            1     GSW   Warriors  ...      68.01     CLE
# 126311         101            1     CLE  Cavaliers  ...      60.01     GSW
# 126312         102            1     CLE  Cavaliers  ...      59.29     GSW
# 126313         103            1     GSW   Warriors  ...      68.52     CLE
#
#          opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126311         101            1     CLE  Cavaliers  ...      60.01     GSW
# 126312         102            1     CLE  Cavaliers  ...      59.29     GSW
# 126313         103            1     GSW   Warriors  ...      68.52     CLE
#
#          opp_fran  opp_pts opp_elo_i opp_elo_n  game_location  game_result  \
# 126311   Warriors      104   1809.98   1813.63              A            L
# 126312   Warriors      105   1813.63   1822.29              H            L
# 126313  Cavaliers       97   1700.74   1692.09              A            W
#
#         forecast notes
# 126311      0.23   NaN
# 126312      0.48   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
print('Basic Statistic NBA Data')
df.describe()
# Out:
# Basic Statistic NBA Data
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# ...

# %%
df = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8b887e80144e> in <module>
# ----> 1 df = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B            some high school      standard
# 1     male        group B            some high school      standard
# 2   female        group B          associate's degree      standard
# 3   female        group C            some high school  free/reduced
# 4     male        group D            some high school      standard
# ..     ...            ...                         ...           ...
# 95    male        group E            some high school      standard
# 96    male        group E                some college      standard
# 97  female        group C            some high school  free/reduced
# 98    male        group C                 high school      standard
# 99  female        group B          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                completed          56             65             64
# ...

# %%
len(df)
# Out:
# 100

# %%
df.shape
# Out:
# (100, 8)

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count      100.00         100.00         100.00
# mean        65.75          67.06          66.19
# std         14.34          14.70          15.06
# min         30.00          25.00          22.00
# 25%         56.00          57.75          54.00
# 50%         66.50          68.00          67.50
# 75%         76.25          79.00          78.00
# max         96.00          95.00          99.00

# %%
exam_data_df = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d26d19725db> in <module>
# ----> 1 exam_data_df = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')
#
# NameError: name 'pd' is not defined

# %%
exam_data_df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B            some high school      standard
# 1     male        group B            some high school      standard
# 2   female        group B          associate's degree      standard
# 3   female        group C            some high school  free/reduced
# 4     male        group D            some high school      standard
# ..     ...            ...                         ...           ...
# 95    male        group E            some high school      standard
# 96    male        group E                some college      standard
# 97  female        group C            some high school  free/reduced
# 98    male        group C                 high school      standard
# 99  female        group B          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                completed          56             65             64
# ...

# %%
exam_data_df[exam_data_df['gender']=='female']['gender'].count()
# Out:
# 41

# %%
exam_data_df=exam_data_df.set_index('gender')

# %%
exam_data_df
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B            some high school      standard
# male          group B            some high school      standard
# female        group B          associate's degree      standard
# female        group C            some high school  free/reduced
# male          group D            some high school      standard
# ...               ...                         ...           ...
# male          group E            some high school      standard
# male          group E                some college      standard
# female        group C            some high school  free/reduced
# male          group C                 high school      standard
# female        group B          associate's degree  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female               completed          56             65             64
# ...

# %%
print('sisa kolom',exam_data_df_trf.axes[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-05fa7ed934d7> in <module>
# ----> 1 print('sisa kolom',exam_data_df_trf.axes[1])
#
# NameError: name 'exam_data_df_trf' is not defined

# %%
exam_data_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d740e7b96780> in <module>
# ----> 1 exam_data_df
#
# NameError: name 'exam_data_df' is not defined

# %%
exam_data_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d740e7b96780> in <module>
# ----> 1 exam_data_df
#
# NameError: name 'exam_data_df' is not defined

# %%
exams_data = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bea3e52f611e> in <module>
# ----> 1 exams_data = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\Latihan1\exams.csv')

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B            some high school      standard
# 1     male        group B            some high school      standard
# 2   female        group B          associate's degree      standard
# 3   female        group C            some high school  free/reduced
# 4     male        group D            some high school      standard
# ..     ...            ...                         ...           ...
# 95    male        group E            some high school      standard
# 96    male        group E                some college      standard
# 97  female        group C            some high school  free/reduced
# 98    male        group C                 high school      standard
# 99  female        group B          associate's degree  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                completed          56             65             64
# ...

# %%
df['math score'].isnull() & df['reading score'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df['math score']
# Out:
# 0     56
# 1     65
# 2     81
# 3     48
# 4     78
#       ..
# 95    59
# 96    66
# 97    49
# 98    63
# 99    53
# Name: math score, Length: 100, dtype: int64

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum(axis = 1)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Length: 100, dtype: int64

# %%
df.('gender').isnull().sum()
# Out:
#   File "<ipython-input-18-58d42fa00183>", line 1
#     df.('gender').isnull().sum()
#        ^
# SyntaxError: invalid syntax

# %%
df.groupby(['gender'])['parental level of education'].count().pieplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a7313aa6ec73> in <module>
# ----> 1 df.groupby(['gender'])['parental level of education'].count().pieplot()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'pieplot'

# %%
df.groupby(['gender'])['parental level of education'].count().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='parental level of education'>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/property_data.csv')

# %%
df
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
cnt = 0
for raw in df['NUM_BATH']:
    if int(raw) == 1
        df.loc[cnt, 'NUM_BATH']=np.nan
    except ValueError:
        pass
    cnt = cnt+1
# Out:
#   File "<ipython-input-1-b76c3429734f>", line 3
#     if int(raw) == 1
#                     ^
# SyntaxError: invalid syntax
