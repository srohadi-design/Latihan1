# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\Latihan1\bank-additional.csv',sep=';')

# %%
df.head(5)
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.tail(5)
# Out:
#       age         job  marital    education default housing loan    contact  \
# 4114   30      admin.  married     basic.6y      no     yes  yes   cellular
# 4115   39      admin.  married  high.school      no     yes   no  telephone
# 4116   27     student   single  high.school      no      no   no   cellular
# 4117   58      admin.  married  high.school      no      no   no   cellular
# 4118   34  management   single  high.school      no     yes   no   cellular
#
#      month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 4114   jul         thu  ...         1    999         0  nonexistent
# 4115   jul         fri  ...         1    999         0  nonexistent
# 4116   may         mon  ...         2    999         1      failure
# 4117   aug         fri  ...         1    999         0  nonexistent
# 4118   nov         wed  ...         1    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df.shape
# Out:
# (4119, 21)

# %%
df
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
df = pd.read_csv(r'C:\Users\user\Latihan1\bank-additional.csv',sep=';')

# %%
df
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
list_of_feature = ['emp.var.rate','cons.price.idx','cons.conf.idx','euribor3m','nr.employed']

# %%
print('list of choosen feature:',list_of_feature)
df[list_of_feature].describe()
# Out:
# list of choosen feature: ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %%
for x in list_of_feature:
    print(df[x].value_counts(),'\n')
# Out:
#  1.4    1626
# -1.8     883
#  1.1     758
# -0.1     392
# -2.9     164
# -3.4     104
# -1.7      87
# -1.1      83
# -3.0      21
# -0.2       1
# Name: emp.var.rate, dtype: int64
#
# 93.994    758
# 93.918    667
# 92.893    597
# 93.444    528
# 94.465    431
# 93.200    386
# 93.075    201
# 92.201     75
# 92.963     75
# 92.431     43
# 94.199     39
# 92.649     36
# 94.027     33
# 94.215     30
# 92.379     25
# 92.843     25
# 94.767     24
# 94.055     24
# 93.876     23
# 93.369     23
# 92.713     21
# 94.601     20
# 93.749     14
# 92.469     14
# 93.798      6
# 92.756      1
# Name: cons.price.idx, dtype: int64
#
# -36.4    758
# -42.7    667
# -46.2    597
# -36.1    528
# -41.8    431
# -42.0    386
# -47.1    201
# -31.4     75
# -40.8     75
# -26.9     43
# -37.5     39
# -30.1     36
# -38.3     33
# -40.3     30
# -50.0     25
# -29.8     25
# -50.8     24
# -39.8     24
# -34.8     23
# -40.0     23
# -33.0     21
# -49.5     20
# -33.6     14
# ...

# %%
df[(df['cons.conf.idx']!='illiterate')][list_of_feature].head()
# Out:
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0          -1.8          92.893          -46.2      1.313       5099.1
# 1           1.1          93.994          -36.4      4.855       5191.0
# 2           1.4          94.465          -41.8      4.962       5228.1
# 3           1.4          94.465          -41.8      4.959       5228.1
# 4          -0.1          93.200          -42.0      4.191       5195.8

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
df['emp.var.rate'].plot(kind='box',figsize=(14,8))
plt.title('Box plot')
plt.ylabel('emp.var.rate')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
y = df['y'].values
print('data y before:',y)
label_encoder = LabelEncoder().fit(y)
#y_after = label_encoder.transform(y)
target_label_encode = label_encoder.transform(y)
#print('data con after:',y_after)
print('data con after:',target_label_encode)
print('class before transform:',label_encoder.classes_)
# Out:
# data y before: ['no' 'no' 'no' ... 'no' 'no' 'no']
# data con after: [0 0 0 ... 0 0 0]
# class before transform: ['no' 'yes']

# %%
df['target_label_encode'] = target_label_encode
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  cons.price.idx  cons.conf.idx  euribor3m  \
# 0   cellular   may         fri  ...          92.893          -46.2      1.313
# 1  telephone   may         fri  ...          93.994          -36.4      4.855
# 2  telephone   jun         wed  ...          94.465          -41.8      4.962
# 3  telephone   jun         fri  ...          94.465          -41.8      4.959
# 4   cellular   nov         mon  ...          93.200          -42.0      4.191
#
# ...

# %%
df_marital_target = df[['marital_label_encode','target_label_encode']]

# %% [markdown]
# from sklearn.preprocessing import LabelEncoder
# target_label = df['cons.price.idx'].values
# print('con  before:',target_label)
# label_encoder = LabelEncoder().fit(target_label)
# target_label_after = label_encoder.transform(target_label)
# print('data con after:',target_label_after)
# print('class before transform:',label_encoder.classes_)

# %%
from sklearn.preprocessing import LabelEncoder
marital_label = df['marital'].values
print('data marital  before:',y)
label_encoder = LabelEncoder().fit(marital_label)
marital_label_after = label_encoder.transform(marital_label)
print('data marital after:',marital_label_after)
print('class before transform:',label_encoder.classes_)
# Out:
# data marital  before: ['no' 'no' 'no' ... 'no' 'no' 'no']
# data marital after: [1 2 1 ... 2 1 2]
# class before transform: ['divorced' 'married' 'single' 'unknown']

# %%
df['marital_label_encode'] = marital_label_after
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  cons.price.idx  cons.conf.idx  euribor3m  \
# 0   cellular   may         fri  ...          92.893          -46.2      1.313
# 1  telephone   may         fri  ...          93.994          -36.4      4.855
# 2  telephone   jun         wed  ...          94.465          -41.8      4.962
# 3  telephone   jun         fri  ...          94.465          -41.8      4.959
# 4   cellular   nov         mon  ...          93.200          -42.0      4.191
#
# ...

# %%
df['marital_label_encode'] = marital_label_after
df[['marital','marital_label_encode','y']].head()
# Out:
#    marital  marital_label_encode   y
# 0  married                     1  no
# 1   single                     2  no
# 2  married                     1  no
# 3  married                     1  no
# 4  married                     1  no

# %%
from sklearn.preprocessing import LabelEncoder
target_label = df['y'].values
print('data marital before:',y)
label_encoder = LabelEncoder().fit(target_label)
target_label_after = label_encoder.transform(target_label)
print('data marital after:',target_label_after)
print('class before transform:',label_encoder.classes_)
# Out:
# data marital before: ['no' 'no' 'no' ... 'no' 'no' 'no']
# data marital after: [0 0 0 ... 0 0 0]
# class before transform: ['no' 'yes']

# %%
df['marital_label_encode'] = marital_label_after
df[['marital','marital_label_encode','y']].head()
# Out:
#    marital  marital_label_encode   y
# 0  married                     1  no
# 1   single                     2  no
# 2  married                     1  no
# 3  married                     1  no
# 4  married                     1  no

# %%
df_marital_target = df[['marital_label_encode','target_label_encode']]
df_marital_target.plot(kind='scatter',x='marital_label_encode',y='target_label_encode')
plt.show()

# %%
df.groupby(by=['target_label_encode','marital_label_encode'])['marital_label_encode'].count()
# Out:
# target_label_encode  marital_label_encode
# 0                    0                        403
#                      1                       2257
#                      2                        998
#                      3                         10
# 1                    0                         43
#                      1                        252
#                      2                        155
#                      3                          1
# Name: marital_label_encode, dtype: int64

# %%
df.groupby(by=['marital','y'])['marital'].count()
# Out:
# marital   y
# divorced  no      403
#           yes      43
# married   no     2257
#           yes     252
# single    no      998
#           yes     155
# unknown   no       10
#           yes       1
# Name: marital, dtype: int64

# %%
df_marital_target.plot(kind='bar',x='marital_label_encode',y='target_label_encode')
plt.show()

# %%
from sklearn.model_selection import train_test_split

features_data = df[['age']].values.reshape(-1,1)
target_data = df[['target_label_encode']].values.reshape(-1,1)
x_train,x_test,y_train,y_test = train_test_split(features_data,target_data,test_size=0.25)
print('shape feature total:',features_data.shape)
print('shape feature train:',x_train.shape)
print('shape feature train:',x_train.shape)
# Out:
# shape feature total: (4119, 1)
# shape feature train: (3089, 1)
# shape feature train: (3089, 1)

# %%
from sklearn.model_selection import train_test_split

features_data = df[['age']].values.reshape(-1,1)
target_data = df[['target_label_encode']].values.reshape(-1,1)

train_test_split(features_data,target_data,test_size=0.25)
# Out:
# [array([[39],
#         [33],
#         [23],
#         ...,
#         [28],
#         [34],
#         [41]], dtype=int64),
#  array([[31],
#         [34],
#         [38],
#         ...,
#         [31],
#         [32],
#         [46]], dtype=int64),
#  array([[0],
#         [0],
#         [0],
#         ...,
#         [0],
#         [0],
#         [0]]),
#  array([[1],
#         [0],
#         [1],
#         ...,
#         [0],
#         [0],
#         [0]])]

# %%
df[['age','target_label_encode']].head()
# Out:
#    age  target_label_encode
# 0   30                    0
# 1   39                    0
# 2   25                    0
# 3   38                    0
# 4   47                    0

# %%
from sklearn.model_selection import train_test_split

features_data = df[['age']].values.reshape(-1,1)
target_data = df[['target_label_encode']].values.reshape(-1,1)

x_train,x_test,y_train,y_test = train_test_split(features_data,target_data,test_size=0.25)
print('shape feature train:',x_train.shape)
print('shape feature test:',x_test.shape)
# Out:
# shape feature train: (3089, 1)
# shape feature test: (1030, 1)

# %% [markdown]
# #Creating Model

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB().fit(x_train,y_train)
model
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# GaussianNB()

# %%
target_prediksi = model.predict(x_train)
target_prediksi
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_train_prediksi = model.predict(x_train)
y_train_prediksi
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
performance_model = model.score(x_train,y_train)
print('performance model :',performance_model)
# Out:
# performance model : 0.8941404985432179

# %%
hasil_confusion_matrik = confusion_matrix(y_train,y_train_prediksi)
hasil_confusion_matrik
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-fc6950a50d5c> in <module>
# ----> 1 hasil_confusion_matrik = confusion_matrix(y_train,y_train_prediksi)
#       2 hasil_confusion_matrik
#
# NameError: name 'confusion_matrix' is not defined

# %%
fig,ax = plt.subplots(figsize=(8,8))
ax.imshow(hasil_confusion_matrik)
ax.grid(False)
for i in range(2):
    for j in range(2):
        ax.text(j,i,hasil_confusion_matrik[j,i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-cd5e089f07ea> in <module>
#       1 fig,ax = plt.subplots(figsize=(8,8))
# ----> 2 ax.imshow(hasil_confusion_matrik)
#       3 ax.grid(False)
#       4 for i in range(2):
#       5     for j in range(2):
#
# NameError: name 'hasil_confusion_matrik' is not defined
