# %%
import pandas as pd

# %%
data_london_df = pd.read_csv('/Users/user/Latihan1/dataset/london_crime_by_lsoa.csv')

# %%
data_london_df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
data_london_total = data_london_df.groupby(['year','month'],axis=0)['value'].sum()

# %%
data_london_total
# Out:
# year  month
# 2008  1        65419
#       2        62626
#       3        61343
#       4        59640
#       5        62587
#                ...
# 2016  8        62666
#       9        61412
#       10       63405
#       11       61064
#       12       62455
# Name: value, Length: 108, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use(['ggplot'])

# %%
line_chart = data_london_total

# %%
line_chart.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='year,month'>

# %%
data_canada_df = pd.read_excel('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/Canada.xlsx?raw=true',sheet_name='Canada by Citizenship',skiprows=range(20),skipfooter=2)

# %%
data_canada_df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
data_canada_df3 = data_canada_df.copy()

# %%
data_canada_total = data_canada_df3.groupby('AreaName',axis=0)[1980].sum()

# %%
data_canada_total
# Out:
# AreaName
# Africa                              3951
# Asia                               31025
# Europe                             39760
# Latin America and the Caribbean    13081
# Northern America                    9378
# Oceania                             1942
# Name: 1980, dtype: int64

# %%
data_canada_total.plot(kind='pie',figsize=(14,8),autopct='%1.1f%%',labels=None)
plt.title('Immigration in Canada')
plt.axis('equal')
plt.legend(labels=data_canada_total.index,loc='upper left')
plt.show()

# %%
import pandas as pd

# %%
data_london_df = pd.read_csv('/Users/user/dataset/london_crime_by_lsoa.csv')

# %%
data_london_df
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
data_london_df2 = data_london_df.copy()

# %%
data_london_total = data_london_df2.groupby('borough',axis=0)['value'].sum()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use(['ggplot'])

# %%
data_london_total.plot(kind='pie',figsize=(14,8),autopct='%1.1f%%',labels=None)
plt.title('Total Crime')
plt.axis('equal')
plt.legend(labels=data_london_total.index,loc='upper left')
plt.show()

# %%
data_london_df.groupby('borough')['value'].nunique().plot(kind='bar')
plt.title('Histogram Number of Crime')
plt.show()
